# %% [markdown]
# # Map CV

# %% [markdown]
# ### Map in construction

# %%
from ipywidgets import HTML

from ipyleaflet import Map, Marker, Popup, Icon, AwesomeIcon

center = (37.500000, 15.090278)
m = Map(center=center, zoom=3, close_popup_on_click=False)

icon1 = AwesomeIcon(
    name='fa-user-circle',
    marker_color='blue',
    icon_color='white',
    spin=False
)


field_sites = []
for i, coords in enumerate(zip(field_activity['Lat'],field_activity['Long'])):
    lt, lg = coords
    field_sites.append((lt, lg))
    marker = Marker(location=(lt, lg), icon=icon1)
    message = HTML()
    message.value = field_activity['Location_name'].to_numpy()[i]
    message.description = field_activity['Purpose'].to_numpy()[i]
    marker.popup = message

    m.add_layer(marker)
m
# Out:
# Map(center=[52.204793, 360.121558], close_popup_on_click=False, controls=(ZoomControl(options=['position', 'zo…

# %%
# read csv file
import pandas as pd
field_activity = pd.read_csv('field.csv')
field_activity.dropna(subset=['Lat', 'Long'],inplace=True)
field_activity
# Out:
#      Id       Date                Location_name        Lat       Long  \
# 0     1    2019-10                Monteriggioni  43.347195  11.305125
# 2     3    2020-02                     Lamosano  46.172658  12.386934
# 4     5    2019-02                       Aviano  46.070560  12.594720
# 5     6    2019-03                      Catania  37.500000  15.090278
# 6     7    2019-05                       Asiago  45.875885  11.509620
# 7     8    2019-06                        Tunis  36.806389  10.181667
# 8     9    2019-10                     Tel-Aviv  32.111767  34.801361
# 9    10    2019-10                       Mestre  45.471520  12.240170
# 10   11    2010-01                          Vix  46.366700  -0.866700
# 11   12    2010-01                    Merlimont  50.450000   1.616700
# 12   13    2012-01                         Vars  44.597700   6.691700
# 13   14    2018-05                     Bordeaux  44.833300  -0.566700
# 14   15    2018-01                       Naples  40.853294  14.305573
# 15   16       2016         Chateaux La Louvière  44.833300   6.691700
# 16   17  2016 2017  Saint Michel l’Observatoire  43.916700   5.716700
#
#                                         Coordinator  \
# 0                                         R. Deiana
# 2                                       G. Cassiani
# 4                                       G. Cassiani
# 5                           G. Cassiani; D. Vanella
# 6                                       G. Cassiani
# 7                                       G. Cassiani
# 8                      G. Cassiani; Nimrod Schwartz
# 9                                       G. Cassiani
# 10                                        METIS UMR
# 11                                        METIS UMR
# 12  Sebastien Merckle; Marc Wathelet; Cecile Cornou
# 13                             B. Mary;  M. Schmutz
# 14                                        L. Busato
# 15                          G. Cassiani; M. Schmutz
# 16                                        I. Reiter
#
#                               Purpose  \
# 0                          Archeology
# 2                           Geohazard
# 4                           Geohazard
# 5   Interaction soil-plant-atmosphere
# 6                           Geohazard
# 7   Interaction soil-plant-atmosphere
# 8   Interaction soil-plant-atmosphere
# 9                           Geohazard
# 10                         Archeology
# 11                          Geohazard
# 12                          Geohazard
# 13  Interaction soil-plant-atmosphere
# 14  Interaction soil-plant-atmosphere
# 15  Interaction soil-plant-atmosphere
# 16  Interaction soil-plant-atmosphere
#
#                                                Method  \
# 0                                                 ERT
# 2                                                 ERT
# 4                                            ERT, GPR
# 5                                                 NaN
# 6                                                 ERT
# 7                                                 ERT
# 8                                                 ERT
# 9                                           ERT; MALM
# 10                                            EM, Mag
# 11                             Seismic; ERT; EM; TDEM
# 12                 S, Surface Waves and $ H/V $ ratio
# 13                                                NaN
# 14                                                NaN
# 15  subsurface (geophysical assessment), surface (...
# 16                                                NaN
#
#                                               Abtract  Data  Article
# 0                                                 NaN   NaN      NaN
# 2                                                 NaN   NaN      NaN
# 4                                                 NaN   NaN      NaN
# 5                                                 NaN   NaN      NaN
# 6                                                 NaN   NaN      NaN
# 7                                                 NaN   NaN      NaN
# 8                                                 NaN   NaN      NaN
# 9                                                 NaN   NaN      NaN
# 10                                                NaN   NaN      NaN
# 11  Determination of tectonic structure of a chalk...   NaN      NaN
# 12                                                NaN   NaN      NaN
# 13  experimental benchmarking on IP imaging method...   NaN      NaN
# 14  ECOREMED life project: bioremediation of a con...   NaN      NaN
# 15  geophysical prospecting on Bordeaux vineyard o...   NaN      NaN
# 16                                                NaN   NaN      NaN
