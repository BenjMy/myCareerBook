# %% [markdown]
# # Map CV

# %% [markdown]
# ```{warning}
# 🚧 This page is still under construction 🚧
# ```

# %% [markdown]
# ```{admonition} Note
# The map display all the field surveys I conducted or participated in the data processing. It starts from 2013 to now. Other metadatas are attached in the table such as the type of survey, the ancillary data collected, the PI of the field site.
# ```

# %%
from ipywidgets import HTML

from ipyleaflet import Map, Marker, Popup, Icon, AwesomeIcon
from ipyleaflet import  LegendControl, basemaps
from IPython.display import Markdown

# read csv file
import pandas as pd
field_activity = pd.read_csv('../field.csv')
field_activity.dropna(subset=['Lat', 'Long'],inplace=True)
field_activity = field_activity.sort_values(by='Date',ascending=False)
field_activity
Purposes = field_activity['Purpose'].unique()
Purposes
# Out:
# array(['Interaction soil-plant-atmosphere', 'Hydrology', 'Geohazard',
#        'Archeology'], dtype=object)

# %% [raw]
# from IPython.display import Markdown, display
# def printmd(string):
#     display(Markdown(string))
#
#
# total_field = len(field_activity)
#
# printmd('''
#         Total Number of field activities: {total_field}, among with
#         '''.format(total_field=total_field)
#         )
# for i in Purposes:
#     #printmd('''{i}'''.format(i=i))
#     printmd('''* {} in {}'''.format(sum(field_activity['Purpose']==i),i))

# %%
center = (43.500000, 15.090278)
m = Map(basemap=basemaps.Esri.WorldTopoMap, center=center, zoom=4, zoom_control=False, 
        close_popup_on_click=False)

# define icon for different field activities: archeology, risk assessement, hydrology, ECZ plant soil interaction

icon_archeo = AwesomeIcon(
            name='hammer',
            marker_color='beige',
            icon_color='black',
            spin=False
        )

icon_risk = AwesomeIcon(
            name='exclamation-circle',
            marker_color='red',
        )

icon_hydro = AwesomeIcon(
            name='hand-holding-water',
            marker_color='blue',
        )

icon_vegetation = AwesomeIcon(
            name='seedling',
            marker_color='green',
        )

icon_type = {
            'Archeology': icon_archeo,
            'Geohazard': icon_risk,
            'Hydrology': icon_hydro,
            'Interaction soil-plant-atmosphere': icon_vegetation,
            }


field_sites = []
for i, coords in enumerate(zip(field_activity['Lat'],field_activity['Long'])):
    lt, lg = coords
    field_sites.append((lt, lg))
      
    marker = Marker(location=(lt, lg), icon= icon_type[field_activity['Purpose'].to_numpy()[i]])
    message = HTML()
    message.value = field_activity['Location_name'].to_numpy()[i]
    message.description = field_activity['Purpose'].to_numpy()[i]
    marker.popup = message
    #marker.dragging.disable()
    

    m.add_layer(marker)
    
legend = LegendControl({"Interactions Soil-Plant-Atmosphere":"green", "Geohazards":"red", "Hydrology":"blue",  "Archeology":"beige"}, 
                       name="Field network", 
                       position="topright")
m.add_control(legend)

# %%
m
# Out:
# Map(center=[43.5, 15.090278], close_popup_on_click=False, controls=(AttributionControl(options=['position', 'p…

# %%
display(field_activity)
# Out:
#      Id       Date                Location_name        Lat        Long  \
# 0     1       2023                      Legnaro  45.345650   11.963914
# 1     2       2023              Re-Della-Pietra  43.880000   11.600000
# 2     3       2022                        Noble  35.139236  -97.394753
# 3     4       2022                 Berkeley Lab  37.874921 -122.252898
# 4     5       2021                   Padova Lab  45.406435   11.876761
# 10   11    2020-02                     Lamosano  46.172658   12.386934
# 11   12    2020-02                       Posina  45.791088   11.262517
# 5     6       2020                      Legnaro  45.345650   11.963914
# 6     7       2020                    Valfredda  46.410720   11.843370
# 7     8       2020                       Alento  40.150000   15.133330
# 16   17    2019-10                     Tel-Aviv  32.111767   34.801361
# 8     9    2019-10                Monteriggioni  43.347195   11.305125
# 9    10    2019-10                       Sienna  43.318611   11.330556
# 17   18    2019-10                       Mestre  45.471520   12.240170
# 15   16    2019-06                        Tunis  36.806389   10.181667
# 24   25    2019-05                     Bordeaux  44.833300   -0.566700
# 14   15    2019-05                       Asiago  45.875885   11.509620
# 13   14    2019-03                      Catania  37.500000   15.090278
# 12   13    2019-02                       Aviano  46.070560   12.594720
# 25   26    2018-05                     Bordeaux  44.833300   -0.566700
# 26   27    2018-01                       Naples  40.853294   14.305573
# 19   20       2017                       Vienna  48.210033   16.363449
# 28   29  2016 2017  Saint Michel l’Observatoire  43.916700    5.716700
# 27   28       2016         Chateaux La Louvière  44.833300    6.691700
# 20   21       2014                  Le Tholonet  43.523000    5.513000
# 21   22       2014                        Arles  43.676701    4.627800
# 23   24    2012-01                         Vars  44.597700    6.691700
# 18   19    2010-01                          Vix  46.366700   -0.866700
# 22   23    2010-01                    Merlimont  50.450000    1.616700
#
#                            Coordinator                       Contribution  \
# 0                F. morari, A. Carrera              Processing, Mentoring
# 1                             D. Penna                         Processing
# 2                                Y. Wu                         Processing
# 3                                Y. Wu                         Processing
# 4                          G. Cassiani            Acquisition, Processing
# 10                         G. Cassiani            Acquisition, Processing
# 11                         G. Cassiani            Acquisition, Processing
# 5                           I. Picolli            Acquisition, Processing
# 6                         M. Camporese            Acquisition, Processing
# 7           G. Cassiani, Nunzio Romano            Acquisition, Processing
# 16        G. Cassiani; Nimrod Schwartz                  Conceptualization
# 8                            R. Deiana            Acquisition, Processing
# 9                            R. Deiana                        Acquisition
# 17                         G. Cassiani            Acquisition, Processing
# 15                         G. Cassiani            Acquisition, Processing
# 24                B. Mary;  M. Schmutz            Acquisition, Processing
# 14                         G. Cassiani            Acquisition, Processing
# 13             G. Cassiani; D. Vanella            Acquisition, Processing
# 12                         G. Cassiani            Acquisition, Processing
# 25                B. Mary;  M. Schmutz            Acquisition, Processing
# 26                           L. Busato            Acquisition, Processing
# 19                        A. O. Flores                         Processing
# 28                           I. Reiter            Acquisition, Processing
# 27             G. Cassiani; M. Schmutz            Acquisition, Processing
# 20                             B. Mary            Acquisition, Processing
# 21                             B. Mary            Acquisition, Processing
# 23  S. Merckle; M. Wathelet; C. Cornou  Acquisition, Processing, Training
# 18                           METIS UMR  Acquisition, Processing, Training
# 22                           METIS UMR  Acquisition, Processing, Training
#
#     Data                            Purpose                          Method  \
# 0    NaN  Interaction soil-plant-atmosphere              ERT; Seismic; FDEM
# 1    NaN                          Hydrology         ERT; GPR; Seismic; FDEM
# 2    NaN  Interaction soil-plant-atmosphere                             ERT
# 3    NaN  Interaction soil-plant-atmosphere                             ERT
# 4    NaN  Interaction soil-plant-atmosphere                             NaN
# 10   NaN                          Geohazard                             ERT
# 11   NaN                          Geohazard                             ERT
# 5    NaN  Interaction soil-plant-atmosphere                             ERT
# 6    NaN                          Hydrology                            FDEM
# 7    NaN                          Hydrology                            FDEM
# 16   NaN  Interaction soil-plant-atmosphere                             ERT
# 8    NaN                         Archeology                             ERT
# 9    NaN                         Archeology                             ERT
# 17   NaN                          Geohazard                       ERT; MALM
# 15   NaN  Interaction soil-plant-atmosphere                             ERT
# 24   NaN  Interaction soil-plant-atmosphere                       ERT; MALM
# 14   NaN                          Geohazard                             ERT
# 13   NaN  Interaction soil-plant-atmosphere                             NaN
# 12   NaN                          Geohazard                        ERT; GPR
# 25   NaN  Interaction soil-plant-atmosphere                              IP
# 26   NaN  Interaction soil-plant-atmosphere                       ERT; MALM
# 19   NaN  Interaction soil-plant-atmosphere                       EIS; MALM
# 28   NaN  Interaction soil-plant-atmosphere                             ERT
# 27   NaN  Interaction soil-plant-atmosphere                       ERT; MALM
# 20   NaN  Interaction soil-plant-atmosphere                  SIP; TDIP, ERT
# 21   NaN                          Geohazard                   ERT; Acoustic
# 23   NaN                          Geohazard  S; Surface Waves and H/V ratio
# 18   NaN                         Archeology                         EM; Mag
# 22   NaN                          Geohazard          Seismic; ERT; EM; TDEM
#
#                                    Ancillary measures Project name  \
# 0                                        SWC, Weather     SoCoRisk
# 1   SWC, Weather, Stemflow, Discharge, Groundwater...       WATZON
# 2                      SWC, tensiometers, weather, ET          NaN
# 3           SWC, rhizotron, tensiometers, weather, ET          NaN
# 4                                                 NaN          NaN
# 10                                                NaN          NaN
# 11                                                NaN          NaN
# 5                                                 NaN          NaN
# 6                                                 NaN          NaN
# 7                                 Neutron Probes; SWC          NaN
# 16                                                NaN          NaN
# 8                                                 NaN          NaN
# 9                                                 NaN          NaN
# 17                                                NaN          NaN
# 15                                                NaN          NaN
# 24                                                NaN          NaN
# 14                                                NaN          NaN
# 13                                                NaN          NaN
# 12                                                NaN          NaN
# 25                                                NaN          NaN
# 26  surface (Sap flow) and remotes observation (ev...          NaN
# 19                                                NaN          NaN
# 28                                                NaN          NaN
# 27                                       Plant traits          NaN
# 20                                                NaN          NaN
# 21                                                NaN          NaN
# 23                                                NaN          NaN
# 18                                                NaN          NaN
# 22                                                NaN          NaN
#
#                                              Abstract  Unnamed: 13  \
# 0                                                 NaN          NaN
# 1                                                 NaN          NaN
# 2                                                 NaN          NaN
# 3                                                 NaN          NaN
# 4                                                 NaN          NaN
# 10                                                NaN          NaN
# 11                                                NaN          NaN
# 5                                                 NaN          NaN
# 6                                                 NaN          NaN
# 7                                                 NaN          NaN
# 16                                                NaN          NaN
# 8                                                 NaN          NaN
# 9                                                 NaN          NaN
# 17                                                NaN          NaN
# 15                                                NaN          NaN
# 24  Geophysical prospecting on Bordeaux vineyard o...          NaN
# 14                                                NaN          NaN
# 13                                                NaN          NaN
# 12                                                NaN          NaN
# 25  Experimental benchmarking on IP imaging method...          NaN
# 26  ECOREMED life project: bioremediation of a con...          NaN
# 19                                                NaN          NaN
# 28                                                NaN          NaN
# 27  Geophysical prospecting on Bordeaux vineyard o...          NaN
# 20                                                NaN          NaN
# 21                                                NaN          NaN
# 23                                                NaN          NaN
# 18                                                NaN          NaN
# 22  Determination of tectonic structure of a chalk...          NaN
#
#     Unnamed: 14                     Article
# 0           NaN                         NaN
# 1           NaN                         NaN
# 2           NaN  10.1007/s11104-020-04529-w
# 3           NaN                         NaN
# 4           NaN                         NaN
# 10          NaN                         NaN
# 11          NaN                         NaN
# 5           NaN                         NaN
# 6           NaN                         NaN
# 7           NaN                         NaN
# 16          NaN                         NaN
# 8           NaN                         NaN
# 9           NaN                         NaN
# 17          NaN                         NaN
# 15          NaN                         NaN
# 24          NaN  10.1038/s41598-019-46107-w
# 14          NaN                         NaN
# 13          NaN  10.1038/s41598-019-46107-w
# 12          NaN                         NaN
# 25          NaN                         NaN
# 26          NaN                         NaN
# 19          NaN                         NaN
# 28          NaN                         NaN
# 27          NaN                         NaN
# 20          NaN                         NaN
# 21          NaN  10.1038/s41598-019-46107-w
# 23          NaN                         NaN
# 18          NaN                         NaN
# 22          NaN                         NaN
